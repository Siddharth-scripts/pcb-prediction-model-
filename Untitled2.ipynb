# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 26.9 MB/s eta 0:00:00
# ...
# ERROR: Operation cancelled by user
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/commands/install.py", line 455, in run
#     installed = install_given_reqs(
#                 ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/req/__init__.py", line 70, in install_given_reqs
#     requirement.install(
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/req/req_install.py", line 851, in install
#     install_wheel(
# ...

# %%
from ultralytics import YOLO

# %%
model=YOLO("yolov8n.pt")

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ywwcdKoIkF5FqNxX3U1D")
project = rf.workspace("siddharth-workspace-7zuyz").project("printed-circuit-board-lcqpf")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 36.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 45.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to printed-circuit-board-1 in yolov8:: 100%|██████████| 3388/3388 [00:03<00:00, 882.26it/s]

# %%
# !pip install ultralytics
from ultralytics import YOLO
model=YOLO("yolov8n.pt")
model.train(
    data="/content/printed-circuit-board-1/data.yaml",
    epochs=100,
    imgsz=640,
    batch=8,

    optimizer="AdamW"

)
# Out:
# ...
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/commands/install.py", line 447, in run
#     conflicts = self._determine_conflicts(to_install)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/commands/install.py", line 578, in _determine_conflicts
#     return check_install_conflicts(to_install)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/operations/check.py", line 101, in check_install_conflicts
# ...

# %%
import yaml

# Read the existing data.yaml file
with open('/content/printed-circuit-board-1/data.yaml', 'r') as f:
    data_config = yaml.safe_load(f)

# Update paths in data.yaml
data_config['path'] = './'
data_config['train'] = 'train/images'
data_config['val'] = 'valid/images'
data_config['test'] = 'test/images' # Assuming test set also exists

# Save the updated data.yaml file
with open('/content/printed-circuit-board-1/data.yaml', 'w') as f:
    yaml.dump(data_config, f)

print("Updated data.yaml content:")
with open('/content/printed-circuit-board-1/data.yaml', 'r') as f:
    print(f.read())

# %%
# !ls -R /content/printed-circuit-board-1/
# Out:
# /content/printed-circuit-board-1/:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid
#
# /content/printed-circuit-board-1/test:
# images	labels
#
# /content/printed-circuit-board-1/test/images:
# Arty_Bottom_jpg.rf.166dbb8d1f7fcd4b5d0d15003db2ecf2.jpg
# Arty_Bottom_jpg.rf.423a75fa109d544885a8f3ec1adc7e61.jpg
# Arty_Top_jpg.rf.8224294f3c8dd701e641ce457911b07d.jpg
# Arty_Top_jpg.rf.92de852d01408cd98e1dcef9ee12c138.jpg
# ATTIOT_Bottom_jpg.rf.5f387652ea6c3b21ea60218a59853e8d.jpg
# ATTIOT_Bottom_jpg.rf.abc81f69a2a08b7c33eb738f17feb8c8.jpg
# DuetWIFI_Top_png_jpg.rf.68edcc2324c67793123e3bc9cdb40068.jpg
# DuetWIFI_Top_png_jpg.rf.9b3dcf4d2ea9ef38334cd9cb1a6d699a.jpg
# pcb107rec1_jpg.rf.653e97ad62ef43de22f3d0e76245b7bd.jpg
# pcb107rec1_jpg.rf.ca43d4aa47e1a52ba27024552dc262ea.jpg
# pcb112rec1_jpg.rf.9ca0cfe5e46b0789e99fb124b75b9e98.jpg
# pcb112rec1_jpg.rf.a3354cea31260a2dc9804bc09be41dad.jpg
# pcb115rec1_jpg.rf.11f971ccc7042b21f94080324b5f1802.jpg
# ...

# %%
from ultralytics import YOLO
import cv2
import os

# -----------------------------
# Paths
# -----------------------------
MODEL_PATH = "/content/runs/detect/train2/weights/best.pt"
IMAGE_PATH = "/content/IMG_20251111_112850.jpg"   # <-- change to your image path
OUTPUT_DIR = "/content/predictions"

os.makedirs(OUTPUT_DIR, exist_ok=True)

# -----------------------------
# Load model
# -----------------------------
model = YOLO(MODEL_PATH)

# -----------------------------
# Run inference
# -----------------------------
results = model.predict(
    source=IMAGE_PATH,
    conf=0.25,
    save=True,
    project=OUTPUT_DIR,
    name="result"
)

print("✅ Prediction completed")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2164603462.py in <cell line: 0>()
# ----> 1 from ultralytics import YOLO
#       2 import cv2
#       3 import os
#       4
#       5 # -----------------------------
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
